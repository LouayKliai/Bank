# %% [markdown]
# <a href="https://colab.research.google.com/github/LouayKliai/Bank/blob/main/BookScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 10.3 MB/s eta 0:00:00
# ...

# %%
# %ls
# Out:
# sample_data/

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# !scrapy startproject FreeCodeTry
# Out:
# New Scrapy project 'FreeCodeTry', using template directory '/usr/local/lib/python3.10/dist-packages/scrapy/templates/project', created in:
#     /content/sample_data/FreeCodeTry
#
# You can start your first spider with:
#     cd FreeCodeTry
#     scrapy genspider example example.com

# %%
# %ls
# %cd FreeCodeTry/FreeCodeTry/spiders
# %ls
# Out:
# anscombe.json*               california_housing_train.csv  mnist_test.csv         README.md*
# california_housing_test.csv  FreeCodeTry/                  mnist_train_small.csv
# /content/sample_data/FreeCodeTry/FreeCodeTry/spiders
# __init__.py

# %%
# !scrapy genspider bookspider books.toscrape.com
# Out:
# Created spider 'bookspider' using template 'basic' in module:
#   FreeCodeTry.spiders.bookspider

# %%
# !scrapy shell
# Out:
# 2023-11-07 02:19:28 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: FreeCodeTry)
# 2023-11-07 02:19:28 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Linux-5.15.120+-x86_64-with-glibc2.35
# 2023-11-07 02:19:28 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-07 02:19:28 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-11-07 02:19:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-07 02:19:28 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-11-07 02:19:28 [scrapy.extensions.telnet] INFO: Telnet Password: e32ce8636f32f02f
# 2023-11-07 02:19:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# !scrapy shell
# Out:
# 2023-11-07 02:20:59 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: FreeCodeTry)
# 2023-11-07 02:20:59 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Linux-5.15.120+-x86_64-with-glibc2.35
# 2023-11-07 02:20:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-07 02:20:59 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-11-07 02:20:59 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-07 02:20:59 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-11-07 02:20:59 [scrapy.extensions.telnet] INFO: Telnet Password: 5b915db31559d358
# 2023-11-07 02:20:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
# %cd FreeCodeTry/FreeCodeTry/spiders
# Out:
# /content/sample_data/FreeCodeTry/FreeCodeTry/spiders

# %%
# %ls
# Out:
# bookspider.py  __init__.py  __pycache__/

# %%
# !scrapy crawl bookspider
# Out:
# 2023-11-07 03:40:22 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: FreeCodeTry)
# 2023-11-07 03:40:22 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Linux-5.15.120+-x86_64-with-glibc2.35
# 2023-11-07 03:40:22 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-07 03:40:22 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-11-07 03:40:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-07 03:40:22 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-11-07 03:40:22 [scrapy.extensions.telnet] INFO: Telnet Password: 0472f6e6adf8f254
# 2023-11-07 03:40:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# !scrapy crawl bookspider -o bookData.json
# Out:
# 2023-11-07 03:40:45 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: FreeCodeTry)
# 2023-11-07 03:40:45 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Linux-5.15.120+-x86_64-with-glibc2.35
# 2023-11-07 03:40:45 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-07 03:40:45 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-11-07 03:40:45 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-07 03:40:45 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-11-07 03:40:45 [scrapy.extensions.telnet] INFO: Telnet Password: 899acbb89df24502
# 2023-11-07 03:40:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# %%writefile
# import scrapy
#
#
# class BookspiderSpider(scrapy.Spider):
#     name = "bookspider"
#     allowed_domains = ["books.toscrape.com"]
#     start_urls = ["https://books.toscrape.com"]
#
#     def parse(self, response):
#         books=response.css('article.product_pod')
#         for book in books:
#             relative_url=response.css('h3 a::attr(href)').get()
#             if 'catalogue/' in relative_url:
#               book_url='https://books.toscrape.com/'+relative_url
#             else:
#               book_url='https://books.toscrape.com/catalogue/'+relative_url
#             yield response.follow(book_url,callback=self.parse_book_page)
#
#         next_page=response.css('li.next a::attr(href)').get()
#         if next_page is not None:
#            if 'catalogue/' in next_page:
#               next_page_url='https://books.toscrape.com/'+next_page
#            else:
#               next_page_url='https://books.toscrape.com/catalogue/'+next_page
#            yield response.follow(next_page_url,callback=self.parse)
#
#
#
#     def parse_book_page(self,response):
#       table_rows=response.css('table tr')
#       yield{
#             'title':response.css('div.product_main h1::text').get(),
#             'description':response.xpath('//*[@id="content_inner"]/article/p/text').get(),
#             'price_excl_tax':table_rows[2].css('td::text').get(),
#             'categorie':response.xpath('//*[@id="default"]/div/div/ul/li[3]/a/text').get()
# }
